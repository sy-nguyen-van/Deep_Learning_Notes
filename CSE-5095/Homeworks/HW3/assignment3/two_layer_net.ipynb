# %% [markdown]
# # Implementing a 2-Layer Neural Network
# In this exercise we will develop a 2-layer neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset. In general, ReLU activation works the best. So ReLU instead of sigmoid will be used in the assignments afterwards.

# %%
# A bit of setup
import numpy as np
import matplotlib.pyplot as plt
from lib.classifiers.neural_net import TwoLayerNet
from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

np.random.seed(1)

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `lib/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `lib/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X,y=None,reg=0.0)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
loss
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13
# np.float64(1.3037878913298202)

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from lib.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447646e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.02.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149607938732093

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from lib.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'lib/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302970
# iteration 100 / 1000: loss 2.302474
# iteration 200 / 1000: loss 2.297076
# iteration 300 / 1000: loss 2.257328
# iteration 400 / 1000: loss 2.230484
# iteration 500 / 1000: loss 2.150620
# iteration 600 / 1000: loss 2.080736
# iteration 700 / 1000: loss 2.054914
# iteration 800 / 1000: loss 1.979290
# iteration 900 / 1000: loss 2.039101
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from lib.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?** Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.

# %%
best_net = None # store the best model into this 

best_val = -1
results = {}

#################################################################################
# TODO: Tune hyperparameters using the validation set. The best trained model   #
# will be stored in best_net.                                                   #
#################################################################################
hidden_sizes = [50, 100, 150]          #  hidden layers
learning_rates = [1e-3, 1e-4, 2e-4]    #  learning rates
regs = [0.005, 0.01, 0.02]              #  L2 regularizations
#################################################################################
#                              END OF YOUR CODE                                 #
#################################################################################

# Tweaking hyperparameters by hand can be fun, but you might find it useful to 
# write code to sweep through possible combinations of hyperparameters          
# automatically like we did on the previous exercises.                          
#
grid_search=[(x,y,z) for x in hidden_sizes for y in learning_rates for z in regs]

for hidden_size,lr,reg in grid_search:
    
    net = TwoLayerNet(input_size, hidden_size, num_classes)

    # Train the network
    net.train(X_train, y_train, X_val, y_val,
                num_iters=3000, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg, verbose=True)

    # Predict on the validation set and compute accuracy
    val_accuracy = (net.predict(X_val) == y_val).mean()
    print('Validation accuracy: ', val_accuracy)
    
    results[(hidden_size,lr,reg)]=val_accuracy
    
    if val_accuracy > best_val:
        best_val = val_accuracy
        best_net = net

# Print out results.
for hidden_size, lr, reg in sorted(results):
    val_accuracy = results[(hidden_size, lr, reg)]
    print('hidden_size %d lr %e reg %e val accuracy: %f' % (
                hidden_size, lr, reg, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 3000: loss 2.302588
# iteration 100 / 3000: loss 1.910023
# iteration 200 / 3000: loss 1.764837
# iteration 300 / 3000: loss 1.703164
# iteration 400 / 3000: loss 1.550816
# iteration 500 / 3000: loss 1.606254
# iteration 600 / 3000: loss 1.476049
# iteration 700 / 3000: loss 1.640534
# iteration 800 / 3000: loss 1.479792
# iteration 900 / 3000: loss 1.604615
# iteration 1000 / 3000: loss 1.562651
# iteration 1100 / 3000: loss 1.502355
# iteration 1200 / 3000: loss 1.487258
# iteration 1300 / 3000: loss 1.457165
# iteration 1400 / 3000: loss 1.436253
# iteration 1500 / 3000: loss 1.435092
# iteration 1600 / 3000: loss 1.336731
# iteration 1700 / 3000: loss 1.417303
# iteration 1800 / 3000: loss 1.296376
# iteration 1900 / 3000: loss 1.289681
# iteration 2000 / 3000: loss 1.325128
# iteration 2100 / 3000: loss 1.356815
# iteration 2200 / 3000: loss 1.256850
# iteration 2300 / 3000: loss 1.343178
# iteration 2400 / 3000: loss 1.197579
# iteration 2500 / 3000: loss 1.182608
# iteration 2600 / 3000: loss 1.109595
# iteration 2700 / 3000: loss 1.349431
# iteration 2800 / 3000: loss 1.219439
# iteration 2900 / 3000: loss 1.125057
# Validation accuracy:  0.513
# iteration 0 / 3000: loss 2.302611
# iteration 100 / 3000: loss 1.880346
# iteration 200 / 3000: loss 1.775001
# iteration 300 / 3000: loss 1.672616
# iteration 400 / 3000: loss 1.678939
# iteration 500 / 3000: loss 1.510151
# iteration 600 / 3000: loss 1.503155
# iteration 700 / 3000: loss 1.600379
# iteration 800 / 3000: loss 1.520154
# iteration 900 / 3000: loss 1.550044
# iteration 1000 / 3000: loss 1.461451
# iteration 1100 / 3000: loss 1.342085
# iteration 1200 / 3000: loss 1.468888
# iteration 1300 / 3000: loss 1.559583
# iteration 1400 / 3000: loss 1.450444
# iteration 1500 / 3000: loss 1.342347
# iteration 1600 / 3000: loss 1.382800
# iteration 1700 / 3000: loss 1.591936
# iteration 1800 / 3000: loss 1.400886
# iteration 1900 / 3000: loss 1.359734
# iteration 2000 / 3000: loss 1.299160
# iteration 2100 / 3000: loss 1.417033
# iteration 2200 / 3000: loss 1.389147
# iteration 2300 / 3000: loss 1.270137
# iteration 2400 / 3000: loss 1.260851
# iteration 2500 / 3000: loss 1.283962
# iteration 2600 / 3000: loss 1.215269
# iteration 2700 / 3000: loss 1.263256
# iteration 2800 / 3000: loss 1.341974
# iteration 2900 / 3000: loss 1.271987
# Validation accuracy:  0.523
# iteration 0 / 3000: loss 2.302656
# iteration 100 / 3000: loss 1.947366
# iteration 200 / 3000: loss 1.821116
# iteration 300 / 3000: loss 1.585443
# iteration 400 / 3000: loss 1.640282
# iteration 500 / 3000: loss 1.702673
# iteration 600 / 3000: loss 1.594967
# iteration 700 / 3000: loss 1.396410
# iteration 800 / 3000: loss 1.714838
# iteration 900 / 3000: loss 1.479702
# iteration 1000 / 3000: loss 1.395820
# iteration 1100 / 3000: loss 1.455977
# iteration 1200 / 3000: loss 1.423228
# iteration 1300 / 3000: loss 1.401414
# iteration 1400 / 3000: loss 1.348639
# iteration 1500 / 3000: loss 1.361707
# iteration 1600 / 3000: loss 1.428995
# iteration 1700 / 3000: loss 1.411343
# iteration 1800 / 3000: loss 1.394555
# iteration 1900 / 3000: loss 1.322409
# iteration 2000 / 3000: loss 1.257802
# iteration 2100 / 3000: loss 1.261029
# iteration 2200 / 3000: loss 1.342957
# iteration 2300 / 3000: loss 1.164436
# iteration 2400 / 3000: loss 1.276614
# iteration 2500 / 3000: loss 1.472550
# iteration 2600 / 3000: loss 1.311159
# iteration 2700 / 3000: loss 1.233380
# iteration 2800 / 3000: loss 1.245115
# iteration 2900 / 3000: loss 1.457828
# Validation accuracy:  0.514
# iteration 0 / 3000: loss 2.302615
# iteration 100 / 3000: loss 2.302054
# iteration 200 / 3000: loss 2.297344
# iteration 300 / 3000: loss 2.270547
# iteration 400 / 3000: loss 2.224589
# iteration 500 / 3000: loss 2.145896
# iteration 600 / 3000: loss 2.080490
# iteration 700 / 3000: loss 2.067541
# iteration 800 / 3000: loss 2.038186
# iteration 900 / 3000: loss 2.047031
# iteration 1000 / 3000: loss 1.950661
# iteration 1100 / 3000: loss 2.007650
# iteration 1200 / 3000: loss 1.901631
# iteration 1300 / 3000: loss 1.940918
# iteration 1400 / 3000: loss 1.883782
# iteration 1500 / 3000: loss 1.840785
# iteration 1600 / 3000: loss 1.859839
# iteration 1700 / 3000: loss 1.824645
# iteration 1800 / 3000: loss 1.790011
# iteration 1900 / 3000: loss 1.786537
# iteration 2000 / 3000: loss 1.773412
# iteration 2100 / 3000: loss 1.782369
# iteration 2200 / 3000: loss 1.781484
# iteration 2300 / 3000: loss 1.651186
# iteration 2400 / 3000: loss 1.805284
# iteration 2500 / 3000: loss 1.745696
# iteration 2600 / 3000: loss 1.699362
# iteration 2700 / 3000: loss 1.728105
# iteration 2800 / 3000: loss 1.704642
# iteration 2900 / 3000: loss 1.789442
# Validation accuracy:  0.386
# iteration 0 / 3000: loss 2.302569
# iteration 100 / 3000: loss 2.302321
# iteration 200 / 3000: loss 2.297307
# iteration 300 / 3000: loss 2.269542
# iteration 400 / 3000: loss 2.178811
# iteration 500 / 3000: loss 2.161622
# iteration 600 / 3000: loss 2.092514
# iteration 700 / 3000: loss 2.096839
# iteration 800 / 3000: loss 1.911894
# iteration 900 / 3000: loss 1.980033
# iteration 1000 / 3000: loss 2.048848
# iteration 1100 / 3000: loss 1.934280
# iteration 1200 / 3000: loss 1.954192
# iteration 1300 / 3000: loss 1.830166
# iteration 1400 / 3000: loss 1.879731
# iteration 1500 / 3000: loss 1.848588
# iteration 1600 / 3000: loss 1.820449
# iteration 1700 / 3000: loss 1.732084
# iteration 1800 / 3000: loss 1.833154
# iteration 1900 / 3000: loss 1.766322
# iteration 2000 / 3000: loss 1.729482
# iteration 2100 / 3000: loss 1.756760
# iteration 2200 / 3000: loss 1.763325
# iteration 2300 / 3000: loss 1.708389
# iteration 2400 / 3000: loss 1.794078
# iteration 2500 / 3000: loss 1.732165
# iteration 2600 / 3000: loss 1.790457
# iteration 2700 / 3000: loss 1.685220
# iteration 2800 / 3000: loss 1.788099
# iteration 2900 / 3000: loss 1.752264
# Validation accuracy:  0.389
# iteration 0 / 3000: loss 2.302621
# iteration 100 / 3000: loss 2.302267
# iteration 200 / 3000: loss 2.297936
# iteration 300 / 3000: loss 2.268532
# iteration 400 / 3000: loss 2.224611
# iteration 500 / 3000: loss 2.084184
# iteration 600 / 3000: loss 2.008301
# iteration 700 / 3000: loss 2.072922
# iteration 800 / 3000: loss 2.039565
# iteration 900 / 3000: loss 1.960746
# iteration 1000 / 3000: loss 2.038244
# iteration 1100 / 3000: loss 1.955047
# iteration 1200 / 3000: loss 1.932908
# iteration 1300 / 3000: loss 1.921377
# iteration 1400 / 3000: loss 1.837886
# iteration 1500 / 3000: loss 1.867750
# iteration 1600 / 3000: loss 1.852277
# iteration 1700 / 3000: loss 1.808926
# iteration 1800 / 3000: loss 1.861331
# iteration 1900 / 3000: loss 1.811013
# iteration 2000 / 3000: loss 1.783977
# iteration 2100 / 3000: loss 1.708453
# iteration 2200 / 3000: loss 1.735962
# iteration 2300 / 3000: loss 1.791369
# iteration 2400 / 3000: loss 1.735978
# iteration 2500 / 3000: loss 1.623335
# iteration 2600 / 3000: loss 1.656604
# iteration 2700 / 3000: loss 1.685798
# iteration 2800 / 3000: loss 1.754557
# iteration 2900 / 3000: loss 1.674992
# Validation accuracy:  0.391
# iteration 0 / 3000: loss 2.302574
# iteration 100 / 3000: loss 2.295612
# iteration 200 / 3000: loss 2.156111
# iteration 300 / 3000: loss 2.020191
# iteration 400 / 3000: loss 1.955065
# iteration 500 / 3000: loss 1.907189
# iteration 600 / 3000: loss 1.811231
# iteration 700 / 3000: loss 1.827741
# iteration 800 / 3000: loss 1.817118
# iteration 900 / 3000: loss 1.879036
# iteration 1000 / 3000: loss 1.751169
# iteration 1100 / 3000: loss 1.739791
# iteration 1200 / 3000: loss 1.728021
# iteration 1300 / 3000: loss 1.752908
# iteration 1400 / 3000: loss 1.674699
# iteration 1500 / 3000: loss 1.772036
# iteration 1600 / 3000: loss 1.682354
# iteration 1700 / 3000: loss 1.614511
# iteration 1800 / 3000: loss 1.629826
# iteration 1900 / 3000: loss 1.589988
# iteration 2000 / 3000: loss 1.667763
# iteration 2100 / 3000: loss 1.620243
# iteration 2200 / 3000: loss 1.622850
# iteration 2300 / 3000: loss 1.654705
# iteration 2400 / 3000: loss 1.547538
# iteration 2500 / 3000: loss 1.593809
# iteration 2600 / 3000: loss 1.510688
# iteration 2700 / 3000: loss 1.499714
# iteration 2800 / 3000: loss 1.476494
# iteration 2900 / 3000: loss 1.604433
# Validation accuracy:  0.46
# iteration 0 / 3000: loss 2.302614
# iteration 100 / 3000: loss 2.299576
# iteration 200 / 3000: loss 2.189970
# iteration 300 / 3000: loss 2.122441
# iteration 400 / 3000: loss 2.031076
# iteration 500 / 3000: loss 1.909107
# iteration 600 / 3000: loss 1.878068
# iteration 700 / 3000: loss 1.838320
# iteration 800 / 3000: loss 1.788944
# iteration 900 / 3000: loss 1.741065
# iteration 1000 / 3000: loss 1.670249
# iteration 1100 / 3000: loss 1.729775
# iteration 1200 / 3000: loss 1.757463
# iteration 1300 / 3000: loss 1.772643
# iteration 1400 / 3000: loss 1.688542
# iteration 1500 / 3000: loss 1.632158
# iteration 1600 / 3000: loss 1.610721
# iteration 1700 / 3000: loss 1.647183
# iteration 1800 / 3000: loss 1.585570
# iteration 1900 / 3000: loss 1.646854
# iteration 2000 / 3000: loss 1.630982
# iteration 2100 / 3000: loss 1.579787
# iteration 2200 / 3000: loss 1.646181
# iteration 2300 / 3000: loss 1.593595
# iteration 2400 / 3000: loss 1.599585
# iteration 2500 / 3000: loss 1.621879
# iteration 2600 / 3000: loss 1.606663
# iteration 2700 / 3000: loss 1.518896
# iteration 2800 / 3000: loss 1.475042
# iteration 2900 / 3000: loss 1.464229
# Validation accuracy:  0.466
# iteration 0 / 3000: loss 2.302616
# iteration 100 / 3000: loss 2.298939
# iteration 200 / 3000: loss 2.154097
# iteration 300 / 3000: loss 2.072085
# iteration 400 / 3000: loss 1.936731
# iteration 500 / 3000: loss 1.940356
# iteration 600 / 3000: loss 1.859995
# iteration 700 / 3000: loss 1.780461
# iteration 800 / 3000: loss 1.836484
# iteration 900 / 3000: loss 1.742379
# iteration 1000 / 3000: loss 1.792312
# iteration 1100 / 3000: loss 1.748751
# iteration 1200 / 3000: loss 1.660925
# iteration 1300 / 3000: loss 1.747799
# iteration 1400 / 3000: loss 1.776751
# iteration 1500 / 3000: loss 1.569745
# iteration 1600 / 3000: loss 1.616085
# iteration 1700 / 3000: loss 1.705607
# iteration 1800 / 3000: loss 1.581349
# iteration 1900 / 3000: loss 1.724631
# iteration 2000 / 3000: loss 1.715086
# iteration 2100 / 3000: loss 1.686350
# iteration 2200 / 3000: loss 1.465872
# iteration 2300 / 3000: loss 1.527658
# iteration 2400 / 3000: loss 1.612016
# iteration 2500 / 3000: loss 1.596743
# iteration 2600 / 3000: loss 1.607530
# iteration 2700 / 3000: loss 1.582848
# iteration 2800 / 3000: loss 1.576713
# iteration 2900 / 3000: loss 1.693012
# Validation accuracy:  0.454
# iteration 0 / 3000: loss 2.302624
# iteration 100 / 3000: loss 1.863718
# iteration 200 / 3000: loss 1.698655
# iteration 300 / 3000: loss 1.652731
# iteration 400 / 3000: loss 1.592057
# iteration 500 / 3000: loss 1.585964
# iteration 600 / 3000: loss 1.510156
# iteration 700 / 3000: loss 1.608734
# iteration 800 / 3000: loss 1.449369
# iteration 900 / 3000: loss 1.476604
# iteration 1000 / 3000: loss 1.311181
# iteration 1100 / 3000: loss 1.469239
# iteration 1200 / 3000: loss 1.374852
# iteration 1300 / 3000: loss 1.388070
# iteration 1400 / 3000: loss 1.404241
# iteration 1500 / 3000: loss 1.288524
# iteration 1600 / 3000: loss 1.274287
# iteration 1700 / 3000: loss 1.366187
# iteration 1800 / 3000: loss 1.315489
# iteration 1900 / 3000: loss 1.326349
# iteration 2000 / 3000: loss 1.252379
# iteration 2100 / 3000: loss 1.233533
# iteration 2200 / 3000: loss 1.248493
# iteration 2300 / 3000: loss 1.250034
# iteration 2400 / 3000: loss 1.150196
# iteration 2500 / 3000: loss 1.165708
# iteration 2600 / 3000: loss 1.154984
# iteration 2700 / 3000: loss 1.233639
# iteration 2800 / 3000: loss 1.211906
# iteration 2900 / 3000: loss 1.050122
# Validation accuracy:  0.543
# iteration 0 / 3000: loss 2.302654
# iteration 100 / 3000: loss 2.003478
# iteration 200 / 3000: loss 1.868853
# iteration 300 / 3000: loss 1.675932
# iteration 400 / 3000: loss 1.628862
# iteration 500 / 3000: loss 1.527503
# iteration 600 / 3000: loss 1.477861
# iteration 700 / 3000: loss 1.410832
# iteration 800 / 3000: loss 1.543553
# iteration 900 / 3000: loss 1.365832
# iteration 1000 / 3000: loss 1.499487
# iteration 1100 / 3000: loss 1.305158
# iteration 1200 / 3000: loss 1.421594
# iteration 1300 / 3000: loss 1.339914
# iteration 1400 / 3000: loss 1.401613
# iteration 1500 / 3000: loss 1.388890
# iteration 1600 / 3000: loss 1.312628
# iteration 1700 / 3000: loss 1.200786
# iteration 1800 / 3000: loss 1.378924
# iteration 1900 / 3000: loss 1.379555
# iteration 2000 / 3000: loss 1.261137
# iteration 2100 / 3000: loss 1.215521
# iteration 2200 / 3000: loss 1.153311
# iteration 2300 / 3000: loss 1.151742
# iteration 2400 / 3000: loss 1.129209
# iteration 2500 / 3000: loss 1.133937
# iteration 2600 / 3000: loss 1.252289
# iteration 2700 / 3000: loss 1.202899
# iteration 2800 / 3000: loss 1.123124
# iteration 2900 / 3000: loss 1.273034
# Validation accuracy:  0.53
# iteration 0 / 3000: loss 2.302674
# iteration 100 / 3000: loss 1.910274
# iteration 200 / 3000: loss 1.829351
# iteration 300 / 3000: loss 1.681718
# iteration 400 / 3000: loss 1.544303
# iteration 500 / 3000: loss 1.530758
# iteration 600 / 3000: loss 1.707564
# iteration 700 / 3000: loss 1.490135
# iteration 800 / 3000: loss 1.452893
# iteration 900 / 3000: loss 1.389840
# iteration 1000 / 3000: loss 1.493827
# iteration 1100 / 3000: loss 1.271454
# iteration 1200 / 3000: loss 1.342329
# iteration 1300 / 3000: loss 1.366324
# iteration 1400 / 3000: loss 1.413997
# iteration 1500 / 3000: loss 1.413887
# iteration 1600 / 3000: loss 1.367904
# iteration 1700 / 3000: loss 1.391397
# iteration 1800 / 3000: loss 1.359813
# iteration 1900 / 3000: loss 1.422233
# iteration 2000 / 3000: loss 1.283707
# iteration 2100 / 3000: loss 1.189984
# iteration 2200 / 3000: loss 1.065358
# iteration 2300 / 3000: loss 1.354345
# iteration 2400 / 3000: loss 1.291945
# iteration 2500 / 3000: loss 1.231447
# iteration 2600 / 3000: loss 1.303073
# iteration 2700 / 3000: loss 1.175446
# iteration 2800 / 3000: loss 1.426344
# iteration 2900 / 3000: loss 1.316441
# Validation accuracy:  0.532
# iteration 0 / 3000: loss 2.302615
# iteration 100 / 3000: loss 2.301867
# iteration 200 / 3000: loss 2.292773
# iteration 300 / 3000: loss 2.237953
# iteration 400 / 3000: loss 2.154810
# iteration 500 / 3000: loss 2.120526
# iteration 600 / 3000: loss 2.096597
# iteration 700 / 3000: loss 2.006040
# iteration 800 / 3000: loss 1.968988
# iteration 900 / 3000: loss 1.982313
# iteration 1000 / 3000: loss 1.913918
# iteration 1100 / 3000: loss 1.879581
# iteration 1200 / 3000: loss 1.847446
# iteration 1300 / 3000: loss 1.944186
# iteration 1400 / 3000: loss 1.810974
# iteration 1500 / 3000: loss 1.751122
# iteration 1600 / 3000: loss 1.850503
# iteration 1700 / 3000: loss 1.877932
# iteration 1800 / 3000: loss 1.815685
# iteration 1900 / 3000: loss 1.838145
# iteration 2000 / 3000: loss 1.757417
# iteration 2100 / 3000: loss 1.778871
# iteration 2200 / 3000: loss 1.786566
# iteration 2300 / 3000: loss 1.679480
# iteration 2400 / 3000: loss 1.759936
# iteration 2500 / 3000: loss 1.801710
# iteration 2600 / 3000: loss 1.734288
# iteration 2700 / 3000: loss 1.618124
# iteration 2800 / 3000: loss 1.725251
# iteration 2900 / 3000: loss 1.684895
# Validation accuracy:  0.403
# iteration 0 / 3000: loss 2.302608
# iteration 100 / 3000: loss 2.301502
# iteration 200 / 3000: loss 2.290743
# iteration 300 / 3000: loss 2.227364
# iteration 400 / 3000: loss 2.113765
# iteration 500 / 3000: loss 2.100249
# iteration 600 / 3000: loss 2.086660
# iteration 700 / 3000: loss 1.955370
# iteration 800 / 3000: loss 2.030101
# iteration 900 / 3000: loss 1.955547
# iteration 1000 / 3000: loss 1.896921
# iteration 1100 / 3000: loss 1.939500
# iteration 1200 / 3000: loss 1.821858
# iteration 1300 / 3000: loss 1.817319
# iteration 1400 / 3000: loss 1.801803
# iteration 1500 / 3000: loss 1.854140
# iteration 1600 / 3000: loss 1.806596
# iteration 1700 / 3000: loss 1.835267
# iteration 1800 / 3000: loss 1.775931
# iteration 1900 / 3000: loss 1.896176
# iteration 2000 / 3000: loss 1.857814
# iteration 2100 / 3000: loss 1.831051
# iteration 2200 / 3000: loss 1.808881
# iteration 2300 / 3000: loss 1.709679
# iteration 2400 / 3000: loss 1.768880
# iteration 2500 / 3000: loss 1.630927
# iteration 2600 / 3000: loss 1.723916
# iteration 2700 / 3000: loss 1.624712
# iteration 2800 / 3000: loss 1.739736
# iteration 2900 / 3000: loss 1.671258
# Validation accuracy:  0.397
# iteration 0 / 3000: loss 2.302656
# iteration 100 / 3000: loss 2.301827
# iteration 200 / 3000: loss 2.293215
# iteration 300 / 3000: loss 2.242067
# iteration 400 / 3000: loss 2.159557
# iteration 500 / 3000: loss 2.162360
# iteration 600 / 3000: loss 2.022631
# iteration 700 / 3000: loss 2.022516
# iteration 800 / 3000: loss 1.938191
# iteration 900 / 3000: loss 1.937520
# iteration 1000 / 3000: loss 1.983906
# iteration 1100 / 3000: loss 1.879648
# iteration 1200 / 3000: loss 1.892564
# iteration 1300 / 3000: loss 1.882641
# iteration 1400 / 3000: loss 1.891239
# iteration 1500 / 3000: loss 1.792818
# iteration 1600 / 3000: loss 1.859589
# iteration 1700 / 3000: loss 1.832133
# iteration 1800 / 3000: loss 1.856987
# iteration 1900 / 3000: loss 1.769514
# iteration 2000 / 3000: loss 1.801521
# iteration 2100 / 3000: loss 1.684118
# iteration 2200 / 3000: loss 1.799600
# iteration 2300 / 3000: loss 1.818500
# iteration 2400 / 3000: loss 1.655724
# iteration 2500 / 3000: loss 1.843375
# iteration 2600 / 3000: loss 1.714358
# iteration 2700 / 3000: loss 1.800072
# iteration 2800 / 3000: loss 1.719218
# iteration 2900 / 3000: loss 1.617591
# Validation accuracy:  0.385
# iteration 0 / 3000: loss 2.302618
# iteration 100 / 3000: loss 2.296378
# iteration 200 / 3000: loss 2.169375
# iteration 300 / 3000: loss 2.065814
# iteration 400 / 3000: loss 1.930941
# iteration 500 / 3000: loss 1.857439
# iteration 600 / 3000: loss 1.845785
# iteration 700 / 3000: loss 1.962820
# iteration 800 / 3000: loss 1.840027
# iteration 900 / 3000: loss 1.767924
# iteration 1000 / 3000: loss 1.776998
# iteration 1100 / 3000: loss 1.738616
# iteration 1200 / 3000: loss 1.696140
# iteration 1300 / 3000: loss 1.627889
# iteration 1400 / 3000: loss 1.667682
# iteration 1500 / 3000: loss 1.711076
# iteration 1600 / 3000: loss 1.681366
# iteration 1700 / 3000: loss 1.578601
# iteration 1800 / 3000: loss 1.594281
# iteration 1900 / 3000: loss 1.507304
# iteration 2000 / 3000: loss 1.581359
# iteration 2100 / 3000: loss 1.641381
# iteration 2200 / 3000: loss 1.631454
# iteration 2300 / 3000: loss 1.602504
# iteration 2400 / 3000: loss 1.560986
# iteration 2500 / 3000: loss 1.421477
# iteration 2600 / 3000: loss 1.725283
# iteration 2700 / 3000: loss 1.499134
# iteration 2800 / 3000: loss 1.454608
# iteration 2900 / 3000: loss 1.611123
# Validation accuracy:  0.461
# iteration 0 / 3000: loss 2.302627
# iteration 100 / 3000: loss 2.291278
# iteration 200 / 3000: loss 2.130653
# iteration 300 / 3000: loss 2.073737
# iteration 400 / 3000: loss 1.972744
# iteration 500 / 3000: loss 1.921294
# iteration 600 / 3000: loss 1.802222
# iteration 700 / 3000: loss 1.867970
# iteration 800 / 3000: loss 1.775024
# iteration 900 / 3000: loss 1.770986
# iteration 1000 / 3000: loss 1.824219
# iteration 1100 / 3000: loss 1.653005
# iteration 1200 / 3000: loss 1.746163
# iteration 1300 / 3000: loss 1.667195
# iteration 1400 / 3000: loss 1.689445
# iteration 1500 / 3000: loss 1.700037
# iteration 1600 / 3000: loss 1.673096
# iteration 1700 / 3000: loss 1.627284
# iteration 1800 / 3000: loss 1.536931
# iteration 1900 / 3000: loss 1.624579
# iteration 2000 / 3000: loss 1.623588
# iteration 2100 / 3000: loss 1.485294
# iteration 2200 / 3000: loss 1.741794
# iteration 2300 / 3000: loss 1.643564
# iteration 2400 / 3000: loss 1.592275
# iteration 2500 / 3000: loss 1.512254
# iteration 2600 / 3000: loss 1.499521
# iteration 2700 / 3000: loss 1.395001
# iteration 2800 / 3000: loss 1.482111
# iteration 2900 / 3000: loss 1.588526
# Validation accuracy:  0.452
# iteration 0 / 3000: loss 2.302686
# iteration 100 / 3000: loss 2.295611
# iteration 200 / 3000: loss 2.186922
# iteration 300 / 3000: loss 2.090960
# iteration 400 / 3000: loss 1.924199
# iteration 500 / 3000: loss 2.076134
# iteration 600 / 3000: loss 1.879482
# iteration 700 / 3000: loss 1.799055
# iteration 800 / 3000: loss 1.798568
# iteration 900 / 3000: loss 1.844015
# iteration 1000 / 3000: loss 1.730571
# iteration 1100 / 3000: loss 1.733132
# iteration 1200 / 3000: loss 1.644982
# iteration 1300 / 3000: loss 1.677033
# iteration 1400 / 3000: loss 1.764647
# iteration 1500 / 3000: loss 1.605000
# iteration 1600 / 3000: loss 1.742477
# iteration 1700 / 3000: loss 1.689126
# iteration 1800 / 3000: loss 1.553447
# iteration 1900 / 3000: loss 1.635158
# iteration 2000 / 3000: loss 1.865421
# iteration 2100 / 3000: loss 1.543468
# iteration 2200 / 3000: loss 1.503520
# iteration 2300 / 3000: loss 1.496641
# iteration 2400 / 3000: loss 1.453575
# iteration 2500 / 3000: loss 1.550099
# iteration 2600 / 3000: loss 1.627935
# iteration 2700 / 3000: loss 1.504815
# iteration 2800 / 3000: loss 1.431433
# iteration 2900 / 3000: loss 1.570660
# Validation accuracy:  0.472
# iteration 0 / 3000: loss 2.302627
# iteration 100 / 3000: loss 1.838026
# iteration 200 / 3000: loss 1.735210
# iteration 300 / 3000: loss 1.610855
# iteration 400 / 3000: loss 1.643297
# iteration 500 / 3000: loss 1.596906
# iteration 600 / 3000: loss 1.543220
# iteration 700 / 3000: loss 1.445782
# iteration 800 / 3000: loss 1.412668
# iteration 900 / 3000: loss 1.534275
# iteration 1000 / 3000: loss 1.290092
# iteration 1100 / 3000: loss 1.417816
# iteration 1200 / 3000: loss 1.310640
# iteration 1300 / 3000: loss 1.336357
# iteration 1400 / 3000: loss 1.315435
# iteration 1500 / 3000: loss 1.300628
# iteration 1600 / 3000: loss 1.343576
# iteration 1700 / 3000: loss 1.238907
# iteration 1800 / 3000: loss 1.333137
# iteration 1900 / 3000: loss 1.243374
# iteration 2000 / 3000: loss 1.131386
# iteration 2100 / 3000: loss 1.206934
# iteration 2200 / 3000: loss 1.142514
# iteration 2300 / 3000: loss 1.185328
# iteration 2400 / 3000: loss 1.220435
# iteration 2500 / 3000: loss 1.294783
# iteration 2600 / 3000: loss 1.166614
# iteration 2700 / 3000: loss 1.246405
# iteration 2800 / 3000: loss 1.218452
# iteration 2900 / 3000: loss 1.044227
# Validation accuracy:  0.536
# iteration 0 / 3000: loss 2.302619
# iteration 100 / 3000: loss 2.016930
# iteration 200 / 3000: loss 1.807871
# iteration 300 / 3000: loss 1.564960
# iteration 400 / 3000: loss 1.597092
# iteration 500 / 3000: loss 1.502069
# iteration 600 / 3000: loss 1.487430
# iteration 700 / 3000: loss 1.524515
# iteration 800 / 3000: loss 1.528792
# iteration 900 / 3000: loss 1.242704
# iteration 1000 / 3000: loss 1.333685
# iteration 1100 / 3000: loss 1.442106
# iteration 1200 / 3000: loss 1.377819
# iteration 1300 / 3000: loss 1.329268
# iteration 1400 / 3000: loss 1.325329
# iteration 1500 / 3000: loss 1.348634
# iteration 1600 / 3000: loss 1.309712
# iteration 1700 / 3000: loss 1.528591
# iteration 1800 / 3000: loss 1.264439
# iteration 1900 / 3000: loss 1.274630
# iteration 2000 / 3000: loss 1.337306
# iteration 2100 / 3000: loss 1.159231
# iteration 2200 / 3000: loss 1.043660
# iteration 2300 / 3000: loss 1.226491
# iteration 2400 / 3000: loss 1.323059
# iteration 2500 / 3000: loss 1.245186
# iteration 2600 / 3000: loss 1.311868
# iteration 2700 / 3000: loss 1.241513
# iteration 2800 / 3000: loss 1.120699
# iteration 2900 / 3000: loss 1.175892
# Validation accuracy:  0.521
# iteration 0 / 3000: loss 2.302695
# iteration 100 / 3000: loss 1.913219
# iteration 200 / 3000: loss 1.765036
# iteration 300 / 3000: loss 1.605232
# iteration 400 / 3000: loss 1.584966
# iteration 500 / 3000: loss 1.565940
# iteration 600 / 3000: loss 1.454238
# iteration 700 / 3000: loss 1.394122
# iteration 800 / 3000: loss 1.397581
# iteration 900 / 3000: loss 1.340157
# iteration 1000 / 3000: loss 1.494004
# iteration 1100 / 3000: loss 1.425675
# iteration 1200 / 3000: loss 1.388837
# iteration 1300 / 3000: loss 1.406839
# iteration 1400 / 3000: loss 1.374875
# iteration 1500 / 3000: loss 1.350906
# iteration 1600 / 3000: loss 1.504702
# iteration 1700 / 3000: loss 1.276965
# iteration 1800 / 3000: loss 1.453260
# iteration 1900 / 3000: loss 1.307238
# iteration 2000 / 3000: loss 1.295280
# iteration 2100 / 3000: loss 1.282205
# iteration 2200 / 3000: loss 1.324838
# iteration 2300 / 3000: loss 1.162226
# iteration 2400 / 3000: loss 1.276284
# iteration 2500 / 3000: loss 1.191934
# iteration 2600 / 3000: loss 1.260710
# iteration 2700 / 3000: loss 1.114996
# iteration 2800 / 3000: loss 1.181972
# iteration 2900 / 3000: loss 1.191604
# Validation accuracy:  0.531
# iteration 0 / 3000: loss 2.302551
# iteration 100 / 3000: loss 2.300965
# iteration 200 / 3000: loss 2.286721
# iteration 300 / 3000: loss 2.224823
# iteration 400 / 3000: loss 2.146097
# iteration 500 / 3000: loss 2.066595
# iteration 600 / 3000: loss 2.015847
# iteration 700 / 3000: loss 2.066581
# iteration 800 / 3000: loss 1.988671
# iteration 900 / 3000: loss 1.956200
# iteration 1000 / 3000: loss 1.911713
# iteration 1100 / 3000: loss 1.878643
# iteration 1200 / 3000: loss 1.889368
# iteration 1300 / 3000: loss 1.822917
# iteration 1400 / 3000: loss 1.841854
# iteration 1500 / 3000: loss 1.964486
# iteration 1600 / 3000: loss 1.814820
# iteration 1700 / 3000: loss 1.806505
# iteration 1800 / 3000: loss 1.746697
# iteration 1900 / 3000: loss 1.780833
# iteration 2000 / 3000: loss 1.758864
# iteration 2100 / 3000: loss 1.699553
# iteration 2200 / 3000: loss 1.687897
# iteration 2300 / 3000: loss 1.796534
# iteration 2400 / 3000: loss 1.804543
# iteration 2500 / 3000: loss 1.619862
# iteration 2600 / 3000: loss 1.804806
# iteration 2700 / 3000: loss 1.774783
# iteration 2800 / 3000: loss 1.743205
# iteration 2900 / 3000: loss 1.731014
# Validation accuracy:  0.405
# iteration 0 / 3000: loss 2.302594
# iteration 100 / 3000: loss 2.301389
# iteration 200 / 3000: loss 2.287361
# iteration 300 / 3000: loss 2.224073
# iteration 400 / 3000: loss 2.167840
# iteration 500 / 3000: loss 2.086518
# iteration 600 / 3000: loss 2.073366
# iteration 700 / 3000: loss 2.036025
# iteration 800 / 3000: loss 1.920092
# iteration 900 / 3000: loss 2.029387
# iteration 1000 / 3000: loss 1.860946
# iteration 1100 / 3000: loss 1.898529
# iteration 1200 / 3000: loss 1.823691
# iteration 1300 / 3000: loss 1.894196
# iteration 1400 / 3000: loss 1.823622
# iteration 1500 / 3000: loss 1.803958
# iteration 1600 / 3000: loss 1.814880
# iteration 1700 / 3000: loss 1.722015
# iteration 1800 / 3000: loss 1.711260
# iteration 1900 / 3000: loss 1.686790
# iteration 2000 / 3000: loss 1.701102
# iteration 2100 / 3000: loss 1.765469
# iteration 2200 / 3000: loss 1.779684
# iteration 2300 / 3000: loss 1.708533
# iteration 2400 / 3000: loss 1.660872
# iteration 2500 / 3000: loss 1.690085
# iteration 2600 / 3000: loss 1.761433
# iteration 2700 / 3000: loss 1.658521
# iteration 2800 / 3000: loss 1.660298
# iteration 2900 / 3000: loss 1.762491
# Validation accuracy:  0.39
# iteration 0 / 3000: loss 2.302650
# iteration 100 / 3000: loss 2.301274
# iteration 200 / 3000: loss 2.285542
# iteration 300 / 3000: loss 2.249853
# iteration 400 / 3000: loss 2.155045
# iteration 500 / 3000: loss 2.098875
# iteration 600 / 3000: loss 2.068314
# iteration 700 / 3000: loss 2.028977
# iteration 800 / 3000: loss 1.913126
# iteration 900 / 3000: loss 1.992485
# iteration 1000 / 3000: loss 1.875870
# iteration 1100 / 3000: loss 1.880247
# iteration 1200 / 3000: loss 1.867632
# iteration 1300 / 3000: loss 1.837013
# iteration 1400 / 3000: loss 1.840386
# iteration 1500 / 3000: loss 1.835606
# iteration 1600 / 3000: loss 1.775236
# iteration 1700 / 3000: loss 1.747237
# iteration 1800 / 3000: loss 1.888674
# iteration 1900 / 3000: loss 1.723020
# iteration 2000 / 3000: loss 1.824565
# iteration 2100 / 3000: loss 1.837571
# iteration 2200 / 3000: loss 1.833408
# iteration 2300 / 3000: loss 1.832565
# iteration 2400 / 3000: loss 1.742595
# iteration 2500 / 3000: loss 1.700787
# iteration 2600 / 3000: loss 1.613730
# iteration 2700 / 3000: loss 1.734360
# iteration 2800 / 3000: loss 1.665427
# iteration 2900 / 3000: loss 1.581834
# Validation accuracy:  0.387
# iteration 0 / 3000: loss 2.302619
# iteration 100 / 3000: loss 2.286183
# iteration 200 / 3000: loss 2.169267
# iteration 300 / 3000: loss 2.060308
# iteration 400 / 3000: loss 2.005069
# iteration 500 / 3000: loss 1.892477
# iteration 600 / 3000: loss 1.861385
# iteration 700 / 3000: loss 1.824422
# iteration 800 / 3000: loss 1.801902
# iteration 900 / 3000: loss 1.727712
# iteration 1000 / 3000: loss 1.751132
# iteration 1100 / 3000: loss 1.657789
# iteration 1200 / 3000: loss 1.623539
# iteration 1300 / 3000: loss 1.681504
# iteration 1400 / 3000: loss 1.630185
# iteration 1500 / 3000: loss 1.681956
# iteration 1600 / 3000: loss 1.591978
# iteration 1700 / 3000: loss 1.662020
# iteration 1800 / 3000: loss 1.666746
# iteration 1900 / 3000: loss 1.577278
# iteration 2000 / 3000: loss 1.476190
# iteration 2100 / 3000: loss 1.663207
# iteration 2200 / 3000: loss 1.549067
# iteration 2300 / 3000: loss 1.602550
# iteration 2400 / 3000: loss 1.474810
# iteration 2500 / 3000: loss 1.491588
# iteration 2600 / 3000: loss 1.679173
# iteration 2700 / 3000: loss 1.501787
# iteration 2800 / 3000: loss 1.470457
# iteration 2900 / 3000: loss 1.592490
# Validation accuracy:  0.459
# iteration 0 / 3000: loss 2.302610
# iteration 100 / 3000: loss 2.286687
# iteration 200 / 3000: loss 2.154559
# iteration 300 / 3000: loss 1.975331
# iteration 400 / 3000: loss 1.998717
# iteration 500 / 3000: loss 1.892991
# iteration 600 / 3000: loss 1.772609
# iteration 700 / 3000: loss 1.737263
# iteration 800 / 3000: loss 1.747291
# iteration 900 / 3000: loss 1.799051
# iteration 1000 / 3000: loss 1.821215
# iteration 1100 / 3000: loss 1.720879
# iteration 1200 / 3000: loss 1.727663
# iteration 1300 / 3000: loss 1.695716
# iteration 1400 / 3000: loss 1.833872
# iteration 1500 / 3000: loss 1.650737
# iteration 1600 / 3000: loss 1.578484
# iteration 1700 / 3000: loss 1.752161
# iteration 1800 / 3000: loss 1.530401
# iteration 1900 / 3000: loss 1.592975
# iteration 2000 / 3000: loss 1.557149
# iteration 2100 / 3000: loss 1.628040
# iteration 2200 / 3000: loss 1.577658
# iteration 2300 / 3000: loss 1.578023
# iteration 2400 / 3000: loss 1.562429
# iteration 2500 / 3000: loss 1.606430
# iteration 2600 / 3000: loss 1.555605
# iteration 2700 / 3000: loss 1.640362
# iteration 2800 / 3000: loss 1.582790
# iteration 2900 / 3000: loss 1.455147
# Validation accuracy:  0.458
# iteration 0 / 3000: loss 2.302708
# iteration 100 / 3000: loss 2.295100
# iteration 200 / 3000: loss 2.164302
# iteration 300 / 3000: loss 2.132561
# iteration 400 / 3000: loss 1.952726
# iteration 500 / 3000: loss 1.889898
# iteration 600 / 3000: loss 1.899318
# iteration 700 / 3000: loss 1.863844
# iteration 800 / 3000: loss 1.773129
# iteration 900 / 3000: loss 1.754401
# iteration 1000 / 3000: loss 1.652916
# iteration 1100 / 3000: loss 1.706535
# iteration 1200 / 3000: loss 1.826160
# iteration 1300 / 3000: loss 1.700228
# iteration 1400 / 3000: loss 1.709318
# iteration 1500 / 3000: loss 1.624007
# iteration 1600 / 3000: loss 1.571565
# iteration 1700 / 3000: loss 1.605654
# iteration 1800 / 3000: loss 1.590871
# iteration 1900 / 3000: loss 1.738765
# iteration 2000 / 3000: loss 1.642016
# iteration 2100 / 3000: loss 1.597883
# iteration 2200 / 3000: loss 1.613027
# iteration 2300 / 3000: loss 1.717551
# iteration 2400 / 3000: loss 1.564961
# iteration 2500 / 3000: loss 1.607898
# iteration 2600 / 3000: loss 1.543070
# iteration 2700 / 3000: loss 1.605338
# iteration 2800 / 3000: loss 1.389853
# iteration 2900 / 3000: loss 1.541534
# Validation accuracy:  0.461
# hidden_size 50 lr 1.000000e-04 reg 5.000000e-03 val accuracy: 0.386000
# hidden_size 50 lr 1.000000e-04 reg 1.000000e-02 val accuracy: 0.389000
# hidden_size 50 lr 1.000000e-04 reg 2.000000e-02 val accuracy: 0.391000
# hidden_size 50 lr 2.000000e-04 reg 5.000000e-03 val accuracy: 0.460000
# hidden_size 50 lr 2.000000e-04 reg 1.000000e-02 val accuracy: 0.466000
# hidden_size 50 lr 2.000000e-04 reg 2.000000e-02 val accuracy: 0.454000
# hidden_size 50 lr 1.000000e-03 reg 5.000000e-03 val accuracy: 0.513000
# hidden_size 50 lr 1.000000e-03 reg 1.000000e-02 val accuracy: 0.523000
# hidden_size 50 lr 1.000000e-03 reg 2.000000e-02 val accuracy: 0.514000
# hidden_size 100 lr 1.000000e-04 reg 5.000000e-03 val accuracy: 0.403000
# hidden_size 100 lr 1.000000e-04 reg 1.000000e-02 val accuracy: 0.397000
# hidden_size 100 lr 1.000000e-04 reg 2.000000e-02 val accuracy: 0.385000
# hidden_size 100 lr 2.000000e-04 reg 5.000000e-03 val accuracy: 0.461000
# hidden_size 100 lr 2.000000e-04 reg 1.000000e-02 val accuracy: 0.452000
# hidden_size 100 lr 2.000000e-04 reg 2.000000e-02 val accuracy: 0.472000
# hidden_size 100 lr 1.000000e-03 reg 5.000000e-03 val accuracy: 0.543000
# hidden_size 100 lr 1.000000e-03 reg 1.000000e-02 val accuracy: 0.530000
# hidden_size 100 lr 1.000000e-03 reg 2.000000e-02 val accuracy: 0.532000
# hidden_size 150 lr 1.000000e-04 reg 5.000000e-03 val accuracy: 0.405000
# hidden_size 150 lr 1.000000e-04 reg 1.000000e-02 val accuracy: 0.390000
# hidden_size 150 lr 1.000000e-04 reg 2.000000e-02 val accuracy: 0.387000
# hidden_size 150 lr 2.000000e-04 reg 5.000000e-03 val accuracy: 0.459000
# hidden_size 150 lr 2.000000e-04 reg 1.000000e-02 val accuracy: 0.458000
# hidden_size 150 lr 2.000000e-04 reg 2.000000e-02 val accuracy: 0.461000
# hidden_size 150 lr 1.000000e-03 reg 5.000000e-03 val accuracy: 0.536000
# hidden_size 150 lr 1.000000e-03 reg 1.000000e-02 val accuracy: 0.521000
# hidden_size 150 lr 1.000000e-03 reg 2.000000e-02 val accuracy: 0.531000
# best validation accuracy achieved during cross-validation: 0.543000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.538
